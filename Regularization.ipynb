# %% [markdown]
# <a href="https://colab.research.google.com/github/Samia35-2973/Machine-Learning-Notes/blob/main/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
# Suppress Warnings for clean notebook
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Melbourne_housing_FULL.csv')
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df = df[['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount',
               'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price']]
df.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h     SS  Jellis  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 3  Abbotsford      3    u     VB  Rounds  Northern Metropolitan
# 4  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
#
#    Propertycount  Distance         CouncilArea  Bedroom2  Bathroom  Car  \
# 0         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 1         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 2         4019.0       2.5  Yarra City Council       2.0       1.0  0.0
# 3         4019.0       2.5  Yarra City Council       3.0       2.0  1.0
# 4         4019.0       2.5  Yarra City Council       3.0       2.0  0.0
#
#    Landsize  BuildingArea      Price
# 0     126.0           NaN        NaN
# 1     202.0           NaN  1480000.0
# ...

# %%
df.shape
# Out:
# (34857, 15)

# %%
def checkNaValues():
  for col in df.columns:
    if df[col].isna().any():
      print(col, "is true")
    else:
      print(col, "is false")

# %%
zeroFillCol = ['Bedroom2', 'Bathroom', 'Car', 'Propertycount', 'Distance']
df[zeroFillCol] = df[zeroFillCol].fillna(0)
checkNaValues()
# Out:
# Suburb is false
# Rooms is false
# Type is false
# Method is false
# SellerG is false
# Regionname is true
# Propertycount is false
# Distance is false
# CouncilArea is true
# Bedroom2 is false
# Bathroom is false
# Car is false
# Landsize is true
# BuildingArea is true
# Price is true

# %%
meanFillCol = ['Landsize', 'BuildingArea']
df[meanFillCol] = df[meanFillCol].fillna(df[meanFillCol].mean())

# Since Price is our target we won't do any modifications in it. So nan values will be dropped.
df.dropna(inplace=True)
checkNaValues()
# Out:
# Suburb is false
# Rooms is false
# Type is false
# Method is false
# SellerG is false
# Regionname is false
# Propertycount is false
# Distance is false
# CouncilArea is false
# Bedroom2 is false
# Bathroom is false
# Car is false
# Landsize is false
# BuildingArea is false
# Price is false

# %%
df
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# 5      Abbotsford      3    h     PI         Biggin  Northern Metropolitan
# 6      Abbotsford      4    h     VB         Nelson  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
# ...

# %%
# One hot encoding on categorical features

df = pd.get_dummies(df, drop_first=True)

# %%
x = df.drop(['Price'], axis = 'columns')
x
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car    Landsize  \
# 1          2         4019.0       2.5       2.0       1.0  1.0  202.000000
# 2          2         4019.0       2.5       2.0       1.0  0.0  156.000000
# 4          3         4019.0       2.5       3.0       2.0  0.0  134.000000
# 5          3         4019.0       2.5       3.0       2.0  1.0   94.000000
# 6          4         4019.0       2.5       3.0       1.0  2.0  120.000000
# ...      ...            ...       ...       ...       ...  ...         ...
# 34852      4         6543.0       6.3       4.0       1.0  3.0  593.000000
# 34853      2         6543.0       6.3       2.0       2.0  1.0   98.000000
# 34854      2         6543.0       6.3       2.0       1.0  2.0  220.000000
# 34855      3         6543.0       6.3       0.0       0.0  0.0  593.598993
# 34856      2         6543.0       6.3       2.0       1.0  0.0  250.000000
#
#        BuildingArea  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# ...

# %%
y = df['Price']
y
# Out:
# 1        1480000.0
# 2        1035000.0
# 4        1465000.0
# 5         850000.0
# 6        1600000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 27244, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
model = LinearRegression().fit(x_train, y_train)

# %%
model.score(x_test, y_test)
# Out:
# 0.6496162909337779

# %%
model.score(x_train, y_train)
# Out:
# 0.6862158726673286

# %% [markdown]
# Here training score is 68% buut test score is 51%. Hence it's overfitting for training data which is resulting horrible score for unseen test data.
#
#
# Normal Regression is clearly overfitting the data
#
# ## Using Lasso (L1 Regularized) Regression Model

# %%
lasso_reg = linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(x_test, y_test)
# Out:
# 0.6505211612081262

# %%
lasso_reg.score(x_train, y_train)
# Out:
# 0.6819862199195672

# %% [markdown]
# ## Using Ridge (L2 Regularized) Regression Model

# %%
lasso_reg = linear_model.Ridge(alpha=50, max_iter=100, tol=0.1)
lasso_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(x_test, y_test)
# Out:
# 0.6437938940746808

# %%
lasso_reg.score(x_train, y_train)
# Out:
# 0.670342413006987

# %% [markdown]
# We see that Lasso and Ridge Regularizations prove to be beneficial when our Simple Linear Regression Model overfits. These results may not be that contrast but significant in most cases.Also that L1 & L2 Regularizations are used in Neural Networks too
